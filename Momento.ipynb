# %% [markdown]
# # Momento de Dipolo dos galatos de alquila (WebMO)

# %%
import pandas as pd

# %%
ler = pd.read_csv("/home/luis/analise-galatos/valoresdipolo.csv")

# %%
ler
# Out:
#       Nome  Não-acetilado com H  Não-acetilado sem H  Acetilado com H  \
# 0  Pentila                 0.99               14.041            5.067
# 1   Hexila                 2.49               13.981            5.340
# 2  Heptila                 2.48               15.758            5.303
# 3   Octila                 2.48               17.645            5.290
#
#    Acetilado sem H
# 0           15.619
# 1           15.503
# 2           16.743
# 3           18.220

# %%
from IPython.display import Image

# %%
Image(filename='/home/luis/analise-galatos/img/pentila com H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/hexila com H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/heptila com H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/octila com H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/pentila sem H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/hexila sem H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/heptila sem H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/octila sem H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/acetilpentila com H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/acetilhexila com H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/acetilheptila com H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/acetiloctila com H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/acetilpentila sem H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/acetilhexila sem H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/acetilheptila sem H.png')

# %%
Image(filename='/home/luis/analise-galatos/img/acetiloctila sem H.png')

# %% [markdown]
# Aparentemente, os galatos ionizados (pka~8) deslocam o sentido do momento para o anel. E quanto maior a cadeia alquila, maior o tamanho do momento.
# Com a inserção do grupo acetil tende a "empurrar" o sentido do momento para o grupo carboxila dos galatos.
